# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
wine = pd.read_csv('./datasets/Class_Winequality.csv',sep=';')

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
wine.shape
# Out:
# (4898, 12)

# %%
wine.describe().transpose()
# Out:
#                        count        mean        std      min         25%  \
# fixed acidity         4898.0    6.854788   0.843868  3.80000    6.300000
# volatile acidity      4898.0    0.278241   0.100795  0.08000    0.210000
# citric acid           4898.0    0.334192   0.121020  0.00000    0.270000
# residual sugar        4898.0    6.391415   5.072058  0.60000    1.700000
# chlorides             4898.0    0.045772   0.021848  0.00900    0.036000
# free sulfur dioxide   4898.0   35.308085  17.007137  2.00000   23.000000
# total sulfur dioxide  4898.0  138.360657  42.498065  9.00000  108.000000
# density               4898.0    0.994027   0.002991  0.98711    0.991723
# pH                    4898.0    3.188267   0.151001  2.72000    3.090000
# sulphates             4898.0    0.489847   0.114126  0.22000    0.410000
# alcohol               4898.0   10.514267   1.230621  8.00000    9.500000
# quality               4898.0    5.877909   0.885639  3.00000    5.000000
#
#                             50%       75%        max
# fixed acidity           6.80000    7.3000   14.20000
# volatile acidity        0.26000    0.3200    1.10000
# citric acid             0.32000    0.3900    1.66000
# residual sugar          5.20000    9.9000   65.80000
# chlorides               0.04300    0.0500    0.34600
# free sulfur dioxide    34.00000   46.0000  289.00000
# total sulfur dioxide  134.00000  167.0000  440.00000
# density                 0.99374    0.9961    1.03898
# pH                      3.18000    3.2800    3.82000
# sulphates               0.47000    0.5500    1.08000
# alcohol                10.40000   11.4000   14.20000
# quality                 6.00000    6.0000    9.00000

# %%
X=wine.drop(columns=['quality'],axis=1)

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol
# 0         8.8
# 1         9.5
# 2        10.1
# 3         9.9
# 4         9.9
# ...       ...
# 4893     11.2
# 4894      9.6
# 4895      9.4
# 4896     12.8
# 4897     11.8
#
# [4898 rows x 11 columns]

# %%
y = wine['quality']

# %%
y
# Out:
# 0       6
# 1       6
# 2       6
# 3       6
# 4       6
#        ..
# 4893    6
# 4894    5
# 4895    6
# 4896    7
# 4897    6
# Name: quality, Length: 4898, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=101, stratify=y)

# %%
X_train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2741            6.9             0.615         0.42           12.00      0.067
# 2111            6.5             0.220         0.25           17.10      0.050
# 4265            6.2             0.360         0.22            5.25      0.038
# 3811            7.2             0.280         0.38            2.00      0.052
# 336             6.3             0.230         0.33            1.50      0.036
# ...             ...               ...          ...             ...        ...
# 3156            6.1             0.170         0.42           15.10      0.033
# 582             7.3             0.300         0.22            6.40      0.056
# 3763            6.7             0.390         0.24            2.70      0.017
# 4498            6.8             0.200         0.25            6.20      0.052
# 1844            6.1             0.340         0.46            4.70      0.029
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2741                 24.0                 131.0  0.99727  3.19       0.34
# 2111                 44.0                 138.0  1.00010  3.30       0.37
# 4265                 44.0                 145.0  0.99184  3.22       0.40
# 3811                 23.0                 156.0  0.99120  3.13       0.52
# 336                  15.0                 105.0  0.99100  3.32       0.42
# ...                   ...                   ...      ...   ...        ...
# 3156                 28.0                 124.0  0.99684  2.87       0.47
# 582                  44.0                 168.0  0.99470  3.13       0.35
# 3763                 22.0                  80.0  0.99084  3.03       0.37
# 4498                 22.0                 106.0  0.99350  3.09       0.54
# 1844                 21.0                  94.0  0.99100  3.29       0.62
#
#       alcohol
# 2741      9.3
# 2111      8.8
# 4265     11.2
# 3811     11.1
# 336      11.2
# ...       ...
# 3156      9.5
# 582      10.1
# 3763     11.5
# 4498     10.8
# 1844     12.3
#
# [3428 rows x 11 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler_X_train=scaler.fit_transform(X_train)

# %%
scaler_X_test = scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=10)

# %%
knn.fit(scaler_X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
y_pred = knn.predict(scaler_X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, classification_report

# %%
MAE = mean_absolute_error(y_test,y_pred)

# %%
MAE
# Out:
# 0.5034013605442177

# %%
RMSE = np.sqrt(mean_squared_error(y_test,y_pred))

# %%
RMSE
# Out:
# np.float64(0.7807200583588266)

# %%
print(knn.score(scaler_X_test,y_test))
# Out:
# 0.5469387755102041

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         6
#            4       0.56      0.10      0.17        49
#            5       0.55      0.63      0.59       437
#            6       0.57      0.62      0.60       660
#            7       0.47      0.42      0.45       264
#            8       0.00      0.00      0.00        53
#            9       0.00      0.00      0.00         1
#
#     accuracy                           0.55      1470
#    macro avg       0.31      0.25      0.26      1470
# weighted avg       0.52      0.55      0.53      1470
# d:\Projetos_analise_dados_python\venv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# d:\Projetos_analise_dados_python\venv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# d:\Projetos_analise_dados_python\venv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
